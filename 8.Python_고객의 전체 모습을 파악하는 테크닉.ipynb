# %% [markdown]
# # 8.Python_고객의 전체 모습을 파악하는 테크닉

# %% [markdown]
# * 현재 데이터로 미래 예측하기
# * 문제상황: 스포츠센터 1년간 이용 회원이 늘지않고 있음. 이유를 데이터 분석으로 알아내기.

# %%
import pandas as pd
uselog = pd.read_csv('/Users/icda/pythondata/pyda100-master/3장/use_log.csv')
print(len(uselog))
uselog.head()
# Out:
# 197428
#             log_id customer_id     usedate
# 0  L00000049012330    AS009373  2018-04-01
# 1  L00000049012331    AS015315  2018-04-01
# 2  L00000049012332    AS040841  2018-04-01
# 3  L00000049012333    AS046594  2018-04-01
# 4  L00000049012334    AS073285  2018-04-01

# %%
customer = pd.read_csv('/Users/icda/pythondata/pyda100-master/3장/customer_master.csv')
print(len(customer))
customer.head()
# Out:
# 4192
#   customer_id   name class gender           start_date end_date campaign_id  \
# 0    OA832399   XXXX   C01      F  2015-05-01 00:00:00      NaN         CA1
# 1    PL270116  XXXXX   C01      M  2015-05-01 00:00:00      NaN         CA1
# 2    OA974876  XXXXX   C01      M  2015-05-01 00:00:00      NaN         CA1
# 3    HD024127  XXXXX   C01      F  2015-05-01 00:00:00      NaN         CA1
# 4    HD661448  XXXXX   C03      F  2015-05-01 00:00:00      NaN         CA1
#
#    is_deleted
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
class_master = pd.read_csv('/Users/icda/pythondata/pyda100-master/3장/class_master.csv')
print(len(class_master))
class_master.head()
# Out:
# 3
#   class class_name  price
# 0   C01       0_종일  10500
# 1   C02       1_주간   7500
# 2   C03       2_야간   6000

# %%
campaign_master = pd.read_csv('/Users/icda/pythondata/pyda100-master/3장/campaign_master.csv')
print(len(campaign_master))
campaign_master.head()
# Out:
# 3
#   campaign_id campaign_name
# 0         CA1          2_일반
# 1         CA2     0_입회비반액할인
# 2         CA3       1_입회비무료

# %% [markdown]
# #### 고객 데이터 가공

# %%
customer_join = pd.merge(customer, class_master, on = "class", how = "left")
customer_join = pd.merge(customer_join, campaign_master, on="campaign_id", how="left")
customer_join.head()
# Out:
#   customer_id   name class gender           start_date end_date campaign_id  \
# 0    OA832399   XXXX   C01      F  2015-05-01 00:00:00      NaN         CA1
# 1    PL270116  XXXXX   C01      M  2015-05-01 00:00:00      NaN         CA1
# 2    OA974876  XXXXX   C01      M  2015-05-01 00:00:00      NaN         CA1
# 3    HD024127  XXXXX   C01      F  2015-05-01 00:00:00      NaN         CA1
# 4    HD661448  XXXXX   C03      F  2015-05-01 00:00:00      NaN         CA1
#
#    is_deleted class_name  price campaign_name
# 0           0       0_종일  10500          2_일반
# 1           0       0_종일  10500          2_일반
# 2           0       0_종일  10500          2_일반
# 3           0       0_종일  10500          2_일반
# 4           0       2_야간   6000          2_일반

# %%
customer_join.isnull().sum()
# Out:
# customer_id         0
# name                0
# class               0
# gender              0
# start_date          0
# end_date         2842
# campaign_id         0
# is_deleted          0
# class_name          0
# price               0
# campaign_name       0
# dtype: int64

# %% [markdown]
# #### 고객 데이터 집계

# %%
customer_join.groupby("class_name").count()["customer_id"]
# Out:
# class_name
# 0_종일    2045
# 1_주간    1019
# 2_야간    1128
# Name: customer_id, dtype: int64

# %%
customer_join.groupby("campaign_name").count()["customer_id"]
# Out:
# campaign_name
# 0_입회비반액할인     650
# 1_입회비무료       492
# 2_일반         3050
# Name: customer_id, dtype: int64

# %%
customer_join.groupby("gender").count()["customer_id"]
# Out:
# gender
# F    1983
# M    2209
# Name: customer_id, dtype: int64

# %%
customer_join.groupby("is_deleted").count()["customer_id"]
# Out:
# is_deleted
# 0    2842
# 1    1350
# Name: customer_id, dtype: int64

# %%
#2018.04.01 부터 2019.03.31 가입 회원 집계
customer_join["start_date"] = pd.to_datetime(customer_join["start_date"])
customer_start = customer_join.loc[customer_join["start_date"] > pd.to_datetime("20180401")]
print(len(customer_start))
# Out:
# 1361

# %% [markdown]
# #### 최신 고객 데이터 집계

# %%
customer_join["end_date"] = pd.to_datetime(customer_join["end_date"])
customer_newer = customer_join.loc[(customer_join["end_date"] >= pd.to_datetime("20190331")) | 
                                    (customer_join["end_date"].isna())]
print(len(customer_newer))
customer_newer["end_date"].unique()
# Out:
# 2953
# <DatetimeArray>
# ['NaT', '2019-03-31 00:00:00']
# Length: 2, dtype: datetime64[ns]

# %%
customer_newer.groupby("class_name").count()["customer_id"]
# Out:
# class_name
# 0_종일    1444
# 1_주간     696
# 2_야간     813
# Name: customer_id, dtype: int64

# %%
customer_newer.groupby("campaign_name").count()["customer_id"]
# Out:
# campaign_name
# 0_입회비반액할인     311
# 1_입회비무료       242
# 2_일반         2400
# Name: customer_id, dtype: int64

# %%
customer_newer.groupby("gender").count()["customer_id"]
# Out:
# gender
# F    1400
# M    1553
# Name: customer_id, dtype: int64

# %% [markdown]
# #### 이용 이력 데이터 집계

# %%
uselog["usedate"] = pd.to_datetime(uselog["usedate"])
uselog["연월"] = uselog["usedate"].dt.strftime("%Y%m")
uselog_months = uselog.groupby(["연월","customer_id"],as_index=False).count()
uselog_months.rename(columns={"log_id":"count"}, inplace=True)
del uselog_months["usedate"]
uselog_months.head()
# Out:
#        연월 customer_id  count
# 0  201804    AS002855      4
# 1  201804    AS009013      2
# 2  201804    AS009373      3
# 3  201804    AS015315      6
# 4  201804    AS015739      7

# %%
#고객별 평균값, 중앙값, 최댓값, 최솟값 집계
uselog_customer = uselog_months.groupby("customer_id").agg(["mean","median","max","min"])["count"]
uselog_customer = uselog_customer.reset_index(drop=False)
uselog_customer.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# ...

# %%
# 데이터 유형 확인
print(uselog_months.dtypes)
# Out:
# 연월             object
# customer_id    object
# count           int64
# dtype: object

# %%
# "count" 열의 데이터 유형을 숫자형으로 변환
uselog_months['count'] = pd.to_numeric(uselog_months['count'], errors='coerce')

# %%
import numpy as np

# 고객별로 평균, 중앙값, 최댓값, 최솟값 계산
uselog_customer_mean = uselog_months.groupby("customer_id")["count"].mean()
uselog_customer_median = uselog_months.groupby("customer_id")["count"].median()
uselog_customer_max = uselog_months.groupby("customer_id")["count"].max()
uselog_customer_min = uselog_months.groupby("customer_id")["count"].min()

# 계산된 결과를 데이터프레임으로 결합
uselog_customer = pd.DataFrame({
    "mean": uselog_customer_mean,
    "median": uselog_customer_median,
    "max": uselog_customer_max,
    "min": uselog_customer_min
}).reset_index()

# 상위 5개 행 출력
uselog_customer.head()
# Out:
#   customer_id      mean  median  max  min
# 0    AS002855  4.500000     5.0    7    2
# 1    AS008805  4.000000     4.0    8    1
# 2    AS009013  2.000000     2.0    2    2
# 3    AS009373  5.083333     5.0    7    3
# 4    AS015233  7.545455     7.0   11    4

# %% [markdown]
# #### 이용 이력 데이터로부터 정기 이용 플래그 작성

# %%
uselog["weekday"] = uselog["usedate"].dt.weekday
uselog_weekday = uselog.groupby(["customer_id","연월","weekday"],
                                as_index = False).count()[["customer_id","연월","weekday","log_id"]]
uselog_weekday.rename(columns={"log_id":"count"},inplace=True)
uselog_weekday.head()
# Out:
#   customer_id      연월  weekday  count
# 0    AS002855  201804        5      4
# 1    AS002855  201805        2      1
# 2    AS002855  201805        5      4
# 3    AS002855  201806        5      5
# 4    AS002855  201807        1      1

# %%
#고객별 최댓값이 4이상일 때 플러그 지정하기
uselog_weekday = uselog_weekday.groupby("customer_id",as_index=False).max()[["customer_id","count"]]
uselog_weekday["routine_flg"] = 0
uselog_weekday["routine_flg"] = uselog_weekday["routine_flg"].where(uselog_weekday["count"]<4, 1)
uselog_weekday.head()
# Out:
#   customer_id  count  routine_flg
# 0    AS002855      5            1
# 1    AS008805      4            1
# 2    AS009013      2            0
# 3    AS009373      5            1
# 4    AS015233      5            1

# %% [markdown]
# #### 고객 데이터와 이용데이터 결합

# %%
customer_join = pd.merge(customer_join, uselog_customer, on="customer_id", how="left")
customer_join.head()
# Out:
#   customer_id   name class gender start_date end_date campaign_id  is_deleted  \
# 0    OA832399   XXXX   C01      F 2015-05-01      NaT         CA1           0
# 1    PL270116  XXXXX   C01      M 2015-05-01      NaT         CA1           0
# 2    OA974876  XXXXX   C01      M 2015-05-01      NaT         CA1           0
# 3    HD024127  XXXXX   C01      F 2015-05-01      NaT         CA1           0
# 4    HD661448  XXXXX   C03      F 2015-05-01      NaT         CA1           0
#
#   class_name  price campaign_name      mean  median  max  min
# 0       0_종일  10500          2_일반  4.833333     5.0    8    2
# 1       0_종일  10500          2_일반  5.083333     5.0    7    3
# 2       0_종일  10500          2_일반  4.583333     5.0    6    3
# 3       0_종일  10500          2_일반  4.833333     4.5    7    2
# 4       2_야간   6000          2_일반  3.916667     4.0    6    1

# %%
customer_join = pd.merge(customer_join, uselog_weekday[["customer_id","routine_flg"]], on="customer_id", how="left")
customer_join.head()
# Out:
#   customer_id   name class gender start_date end_date campaign_id  is_deleted  \
# 0    OA832399   XXXX   C01      F 2015-05-01      NaT         CA1           0
# 1    PL270116  XXXXX   C01      M 2015-05-01      NaT         CA1           0
# 2    OA974876  XXXXX   C01      M 2015-05-01      NaT         CA1           0
# 3    HD024127  XXXXX   C01      F 2015-05-01      NaT         CA1           0
# 4    HD661448  XXXXX   C03      F 2015-05-01      NaT         CA1           0
#
#   class_name  price campaign_name      mean  median  max  min  routine_flg
# 0       0_종일  10500          2_일반  4.833333     5.0    8    2            1
# 1       0_종일  10500          2_일반  5.083333     5.0    7    3            1
# 2       0_종일  10500          2_일반  4.583333     5.0    6    3            1
# 3       0_종일  10500          2_일반  4.833333     4.5    7    2            1
# 4       2_야간   6000          2_일반  3.916667     4.0    6    1            1

# %%
customer_join.isnull().sum()
# Out:
# customer_id         0
# name                0
# class               0
# gender              0
# start_date          0
# end_date         2842
# campaign_id         0
# is_deleted          0
# class_name          0
# price               0
# campaign_name       0
# mean                0
# median              0
# max                 0
# min                 0
# routine_flg         0
# dtype: int64

# %% [markdown]
# #### 회원 기간 계산

# %%
from dateutil.relativedelta import relativedelta
customer_join["calc_date"] = customer_join["end_date"]
customer_join["calc_date"] = customer_join["calc_date"].fillna(pd.to_datetime("20190430"))
customer_join["membership_period"] = 0
for i in range(len(customer_join)):
    delta = relativedelta(customer_join["calc_date"].iloc[i], customer_join["start_date"].iloc[i])
    customer_join["membership_period"].iloc[i] = delta.years*12 + delta.months
customer_join.head()
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#   customer_id   name class gender start_date end_date campaign_id  is_deleted  \
# 0    OA832399   XXXX   C01      F 2015-05-01      NaT         CA1           0
# 1    PL270116  XXXXX   C01      M 2015-05-01      NaT         CA1           0
# 2    OA974876  XXXXX   C01      M 2015-05-01      NaT         CA1           0
# 3    HD024127  XXXXX   C01      F 2015-05-01      NaT         CA1           0
# 4    HD661448  XXXXX   C03      F 2015-05-01      NaT         CA1           0
#
#   class_name  price campaign_name      mean  median  max  min  routine_flg  \
# 0       0_종일  10500          2_일반  4.833333     5.0    8    2            1
# ...

# %%
from dateutil.relativedelta import relativedelta

# "calc_date" 컬럼 생성 및 결측치 처리
customer_join["calc_date"] = customer_join["end_date"]
customer_join["calc_date"] = customer_join["calc_date"].fillna(pd.to_datetime("20190430"))

# "membership_period" 초기화
customer_join["membership_period"] = 0

# 고객별로 가입 기간 계산
for i in range(len(customer_join)):
    delta = relativedelta(customer_join["calc_date"].iloc[i], customer_join["start_date"].iloc[i])
    years_months = delta.years * 12 + delta.months
    customer_join.at[i, "membership_period"] = years_months

customer_join.head()
# Out:
#   customer_id   name class gender start_date end_date campaign_id  is_deleted  \
# 0    OA832399   XXXX   C01      F 2015-05-01      NaT         CA1           0
# 1    PL270116  XXXXX   C01      M 2015-05-01      NaT         CA1           0
# 2    OA974876  XXXXX   C01      M 2015-05-01      NaT         CA1           0
# 3    HD024127  XXXXX   C01      F 2015-05-01      NaT         CA1           0
# 4    HD661448  XXXXX   C03      F 2015-05-01      NaT         CA1           0
#
#   class_name  price campaign_name      mean  median  max  min  routine_flg  \
# 0       0_종일  10500          2_일반  4.833333     5.0    8    2            1
# 1       0_종일  10500          2_일반  5.083333     5.0    7    3            1
# 2       0_종일  10500          2_일반  4.583333     5.0    6    3            1
# 3       0_종일  10500          2_일반  4.833333     4.5    7    2            1
# 4       2_야간   6000          2_일반  3.916667     4.0    6    1            1
#
#    calc_date  membership_period
# ...

# %% [markdown]
# #### 고객 행동의 각종 통계량 파악

# %%
customer_join[["mean","median","max","min"]].describe()
# Out:
#               mean       median          max          min
# count  4192.000000  4192.000000  4192.000000  4192.000000
# mean      5.333127     5.250596     7.823950     3.041269
# std       1.777533     1.874874     2.168959     1.951565
# min       1.000000     1.000000     1.000000     1.000000
# 25%       4.250000     4.000000     7.000000     2.000000
# 50%       5.000000     5.000000     8.000000     3.000000
# 75%       6.416667     6.500000     9.000000     4.000000
# max      12.000000    12.000000    14.000000    12.000000

# %%
customer_join.groupby("routine_flg").count()["customer_id"]
# Out:
# routine_flg
# 0     779
# 1    3413
# Name: customer_id, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.hist(customer_join["membership_period"])
# Out:
# (array([857., 774., 395., 368., 311., 331., 323., 237., 288., 308.]),
#  array([ 1. ,  5.6, 10.2, 14.8, 19.4, 24. , 28.6, 33.2, 37.8, 42.4, 47. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### 탈퇴 회원과 지속 회원의 차이 파악

# %%
customer_end = customer_join.loc[customer_join["is_deleted"]==1]
customer_end.describe()
# Out:
#                 start_date             end_date  is_deleted         price  \
# count                 1350                 1350      1350.0   1350.000000
# mean   2018-01-20 10:45:20  2018-10-17 16:23:28         1.0   8595.555556
# min    2016-05-01 00:00:00  2018-04-30 00:00:00         1.0   6000.000000
# 25%    2017-10-01 00:00:00  2018-06-30 00:00:00         1.0   6000.000000
# 50%    2018-03-01 00:00:00  2018-10-31 00:00:00         1.0   7500.000000
# 75%    2018-06-03 00:00:00  2019-01-31 00:00:00         1.0  10500.000000
# max    2019-02-11 00:00:00  2019-03-31 00:00:00         1.0  10500.000000
# std                    NaN                  NaN         0.0   1949.163652
#
#               mean       median          max          min  routine_flg  \
# count  1350.000000  1350.000000  1350.000000  1350.000000  1350.000000
# mean      3.865474     3.621852     6.461481     1.821481     0.456296
# min       1.000000     1.000000     1.000000     1.000000     0.000000
# ...

# %%
customer_stay = customer_join.loc[customer_join["is_deleted"]==0]
customer_stay.describe()
# Out:
#                           start_date end_date  is_deleted         price  \
# count                           2842        0      2842.0   2842.000000
# mean   2017-04-03 22:42:28.627726848      NaT         0.0   8542.927516
# min              2015-05-01 00:00:00      NaT         0.0   6000.000000
# 25%              2016-05-01 00:00:00      NaT         0.0   6000.000000
# 50%              2017-04-01 00:00:00      NaT         0.0   7500.000000
# 75%              2018-04-05 00:00:00      NaT         0.0  10500.000000
# max              2019-03-15 00:00:00      NaT         0.0  10500.000000
# std                              NaN      NaN         0.0   1977.189779
#
#               mean       median          max          min  routine_flg  \
# count  2842.000000  2842.000000  2842.000000  2842.000000  2842.000000
# mean      6.030288     6.024279     8.471147     3.620690     0.984166
# min       3.166667     3.000000     5.000000     1.000000     0.000000
# ...

# %%
customer_join.to_csv("/Users/icda/pythondata/pyda100-master/3장/customer_join.csv", index=False)
