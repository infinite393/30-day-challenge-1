# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import folium
import json

# matplotlib 한글폰트 지정
plt.rc('font',family='AppleGothic')
plt.rc('axes', unicode_minus=False)

# %%
districts = ["종로구", "중구", "용산구", "성동구", "광진구", "동대문구", "중랑구", "성북구", "강북구", "도봉구",
             "노원구", "은평구", "서대문구", "마포구", "양천구", "강서구", "구로구", "금천구", "영등포구", "동작구",
             "관악구", "서초구", "강남구", "송파구", "강동구"]

daily_population = [318247, 354716, 304379, 364963, 377350, 364022, 345140, 422138, 278204, 260864, 482092, 426210, 
                     399796, 483648, 372405, 565519, 425194, 250268, 550111, 379476, 477312, 622327, 930881, 776019,
                     515485]

data_seoul_d = dict(zip(districts, daily_population))

# %%
geo_json = 'https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'

m4 = folium.Map(
    location=[37.566345, 126.977893], zoom_start=10.5
)

folium.Choropleth(
    geo_data=geo_json,
    name='choropleth',
    data=data_seoul_d,
    columns=['구', '총생활인구'],
    key_on='feature.properties.name',
    fill_color='viridis',
    fill_opacity=0.7,
    line_opacity=0.2,
).add_to(m4)


# 네모 박스로 제목 추가 (스타일 및 좌측 상단 정렬 변경)
title_html = '''
             <div style="position: fixed; 
                         top: 10px; left: 10px; width: 200px; height: 40px; 
                         border:2px solid #555; z-index:9999; font-size:16px;
                         background-color:white; text-align:center;
                         color: black; line-height:40px;"><b>서울시 총생활인구</b></div>
             '''
m4.get_root().html.add_child(folium.Element(title_html))

# 이미지로 저장
# m4.save("서울시총생활인구.html")  # HTML 파일로 저장


m4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29f4a355e16cc1257f9b5a60b3a60630 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#              &lt;div style=&quot;position: fixed;
#                          top: 10px; left: 10px; width: 200px; height: 40px;
#                          border:2px solid #555; z-index:9999; font-size:16px;
#                          background-color:white; text-align:center;
#                          color: black; line-height:40px;&quot;&gt;&lt;b&gt;서울시 총생활인구&lt;/b&gt;&lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29f4a355e16cc1257f9b5a60b3a60630&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29f4a355e16cc1257f9b5a60b3a60630 = L.map(
#                 &quot;map_29f4a355e16cc1257f9b5a60b3a60630&quot;,
#                 {
#                     center: [37.566345, 126.977893],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff8f248f6253c2a9506e713b506be167 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ff8f248f6253c2a9506e713b506be167.addTo(map_29f4a355e16cc1257f9b5a60b3a60630);
#
#
#             var choropleth_bbaf55b3a661bef23132ad7c848ce278 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_058c176988539f63aec0d7cecd0599ca_styler(feature) {
#             switch(feature.properties.code) {
#                 case &quot;11240&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#79d150&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11230&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11220&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#23a783&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11200&quot;: case &quot;11170&quot;: case &quot;11150&quot;: case &quot;11130&quot;: case &quot;11120&quot;: case &quot;11080&quot;: case &quot;11060&quot;: case &quot;11050&quot;: case &quot;11040&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#414386&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11180&quot;: case &quot;11100&quot;: case &quot;11090&quot;: case &quot;11070&quot;: case &quot;11030&quot;: case &quot;11020&quot;: case &quot;11010&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2a778e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_058c176988539f63aec0d7cecd0599ca_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_058c176988539f63aec0d7cecd0599ca = L.geoJson(null, {
#                 onEachFeature: geo_json_058c176988539f63aec0d7cecd0599ca_onEachFeature,
#
#                 style: geo_json_058c176988539f63aec0d7cecd0599ca_styler,
#         });
#
#         function geo_json_058c176988539f63aec0d7cecd0599ca_add (data) {
#             geo_json_058c176988539f63aec0d7cecd0599ca
#                 .addData(data);
#         }
#             geo_json_058c176988539f63aec0d7cecd0599ca_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770

# %%
import pandas as pd
df_seoul_district_office = pd.read_csv('서울시구청위도경도.csv', header=None).iloc[:,:3]
df_seoul_district_office.columns=['구청','위도', '경도']
df_seoul_district_office.head(3)
df_seoul_district_office
# Out:
#        구청         위도          경도
# 0    강남구청  37.517321  127.047381
# 1    강동구청  37.532460  127.123700
# 2    강북구청  37.639790  127.025500
# 3    강서구청  37.550910  126.849600
# 4    관악구청  37.478120  126.951500
# 5    광진구청  37.538380  127.082200
# 6    구로구청  37.495472  126.887638
# 7    금천구청  37.459238  126.898836
# 8    노원구청  37.654080  127.056600
# 9    도봉구청  37.668770  127.047100
# 10  동대문구청  37.574200  127.039800
# 11   동작구청  37.512430  126.939800
# 12   마포구청  37.570030  126.901900
# 13  서대문구청  37.579260  126.936500
# 14   서초구청  37.483590  127.032700
# 15   성동구청  37.563410  127.036900
# 16   성북구청  37.589370  127.016700
# 17   송파구청  37.514450  127.105900
# 18   양천구청  37.516950  126.866600
# 19  영등포구청  37.526350  126.896300
# 20   용산구청  37.532330  126.990700
# 21   은평구청  37.602750  126.929300
# 22   종로구청  37.573470  126.979000
# 23    중구청  37.563760  126.997600
# 24   중랑구청  37.606300  127.093200

# %%
# 지도 생성 
# 지도 중심(서울시청)
loc = (37.56685, 126.9784) 

m = folium.Map(location=loc
            , zoom_start=11
            )

# geojson 문자열을 dict 객체로 파싱

with open('/Users/icda/geojson/서울시_시군구.geojson', mode='r', encoding='utf-8') as f:
    geo = json.loads(f.read())

# 지도에 시군구 경계 추가
#folium.GeoJson(
#    geo
#).add_to(m)


#지도 경계별로 색상 넣기(서울시 총셍활인구 df 사용)
folium.Choropleth(
    geo_data=geo_json,
    name='choropleth',
    data=data_seoul_d,
    columns=['구', '총생활인구'],
    key_on='feature.properties.name',
    fill_color='Blues',
    fill_opacity=0.7,
    line_opacity=0.2,
).add_to(m)



# 마커 추가
for i in range(len(df_seoul_district_office)):
    gu_name = df_seoul_district_office.iloc[i,0]
    lat = df_seoul_district_office.iloc[i,1]
    lon = df_seoul_district_office.iloc[i,2] 
    folium.Circle(location = (lat, lon)
                 , tooltip=gu_name
                 , color='red'
                 , fill=True
                 ).add_to(m)
    
    
# 네모 박스로 제목 추가 (스타일 및 좌측 상단 정렬 변경)
title_html = '''
             <div style="position: fixed; 
                         top: 10px; left: 10px; width: 200px; height: 40px; 
                         border:2px solid #555; z-index:9999; font-size:16px;
                         background-color:white; text-align:center;
                         color: black; line-height:40px;"><b>서울시 구청 위치</b></div>
             '''
m.get_root().html.add_child(folium.Element(title_html))
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9f1ef2d71f9e7387f86fd9815b2a1eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#              &lt;div style=&quot;position: fixed;
#                          top: 10px; left: 10px; width: 200px; height: 40px;
#                          border:2px solid #555; z-index:9999; font-size:16px;
#                          background-color:white; text-align:center;
#                          color: black; line-height:40px;&quot;&gt;&lt;b&gt;서울시 구청 위치&lt;/b&gt;&lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9f1ef2d71f9e7387f86fd9815b2a1eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9f1ef2d71f9e7387f86fd9815b2a1eb = L.map(
#                 &quot;map_c9f1ef2d71f9e7387f86fd9815b2a1eb&quot;,
#                 {
#                     center: [37.56685, 126.9784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8fe4c75fb03e395fc8cd5fe55d39d07 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e8fe4c75fb03e395fc8cd5fe55d39d07.addTo(map_c9f1ef2d71f9e7387f86fd9815b2a1eb);
#
#
#             var choropleth_d1baa02f0bd0cd55b4b8300507ecb72e = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_35132c58de3b6bc3937dfd9f7bf1b09e_styler(feature) {
#             switch(feature.properties.code) {
#                 case &quot;11240&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3182bd&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11230&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08519c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11220&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6baed6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11200&quot;: case &quot;11170&quot;: case &quot;11150&quot;: case &quot;11130&quot;: case &quot;11120&quot;: case &quot;11080&quot;: case &quot;11060&quot;: case &quot;11050&quot;: case &quot;11040&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c6dbef&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11180&quot;: case &quot;11100&quot;: case &quot;11090&quot;: case &quot;11070&quot;: case &quot;11030&quot;: case &quot;11020&quot;: case &quot;11010&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eff3ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ecae1&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_35132c58de3b6bc3937dfd9f7bf1b09e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_35132c58de3b6bc3937dfd9f7bf1b09e = L.geoJson(null, {
#                 onEachFeature: geo_json_35132c58de3b6bc3937dfd9f7bf1b09e_onEachFeature,
#
#                 style: geo_json_35132c58de3b6bc3937dfd9f7bf1b09e_styler,
#         });
#
#         function geo_json_35132c58de3b6bc3937dfd9f7bf1b09e_add (data) {
#             geo_json_35132c58de3b6bc3937dfd9f7bf1b09e
#                 .addData(data);
#         }
#             geo_json_35132c58de3b6bc3937dfd9f7bf1b09e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.1777086050

# %%
df_location = pd.read_csv('중랑구_헬스장좌표.csv').iloc[:,:3]
df_location.columns=['사업장명','위도', '경도']
df_location.head(3)
df_location
# Out:
#             사업장명         위도          경도
# 0   유코치의 바디스토리PT  37.572599  127.084141
# 1         아모르 PT  37.578787  127.091690
# 2          럭키 헬스  37.598387  127.076902
# 3        이코리아스포츠  37.600083  127.102685
# 4         세방헬스클럽  37.579087  127.085268
# ..           ...        ...         ...
# 75      크로스핏 라온3  37.594951  127.081014
# 76          머시써짐  37.605480  127.096127
# 77       크로스핏 레오  37.581125  127.085983
# 78          2034  37.612971  127.078181
# 79          2037  37.611807  127.078238
#
# [80 rows x 3 columns]

# %%
# 지도 중심(중랑구)
lat = 37.606324
lon = 127.092584

loc = (37.606324, 127.092584)

m8 = folium.Map(location=loc
               , zoom_start=13.5
              )


# circle마커 생성 (tooltip :사업장명)
marker_list = []
for i in range(len(df_location)):
    marker = folium.Circle((df_location.iloc[i,1], df_location.iloc[i,2])
                           , tooltip=df_location.iloc[i,0]
                          , radius = 30
                          , color='red'
                          , fill=True)
    marker.add_to(m8)


# 네모 박스로 제목 추가 (스타일 및 좌측 상단 정렬 변경)
title_html = '''
             <div style="position: fixed;
                         top: 10px; left: 10px; width: 200px; height: 40px;
                         border:2px solid #555; z-index:9999; font-size:16px;
                         background-color:white; text-align:center;
                         color: black; line-height:40px;"><b>중랑구 헬스장 개별위치</b></div>
             '''
m8.get_root().html.add_child(folium.Element(title_html))

m8
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81f864dae4c5e38710ab7136ec9fccb5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#              &lt;div style=&quot;position: fixed;
#                          top: 10px; left: 10px; width: 200px; height: 40px;
#                          border:2px solid #555; z-index:9999; font-size:16px;
#                          background-color:white; text-align:center;
#                          color: black; line-height:40px;&quot;&gt;&lt;b&gt;중랑구 헬스장 개별위치&lt;/b&gt;&lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81f864dae4c5e38710ab7136ec9fccb5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81f864dae4c5e38710ab7136ec9fccb5 = L.map(
#                 &quot;map_81f864dae4c5e38710ab7136ec9fccb5&quot;,
#                 {
#                     center: [37.606324, 127.092584],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_04532b02a54b63568ae176e001b3045e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_04532b02a54b63568ae176e001b3045e.addTo(map_81f864dae4c5e38710ab7136ec9fccb5);
#
#
#             var circle_81c6d2de65df0c0f85bd9c334328f39c = L.circle(
#                 [37.57259939, 127.0841405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_81f864dae4c5e38710ab7136ec9fccb5);
#
#
#             circle_81c6d2de65df0c0f85bd9c334328f39c.bindTooltip(
#                 `&lt;div&gt;
#                      유코치의 바디스토리PT
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_9251d192eabd80d25a4c3f71d454490e = L.circle(
#                 [37.57878738, 127.0916896],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_81f864dae4c5e38710ab7136ec9fccb5);
#
#
#             circle_9251d192eabd80d25a4c3f71d454490e.bindTooltip(
#                 `&lt;div&gt;
#                      아모르 PT
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_2ee79f67c3c67c52073419edeb967fd0 = L.circle(
#                 [37.59838725, 127.0769015],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_81f864dae4c5e38710ab7136ec9fccb5);
#
#
#             circle_2ee79f67c3c67c52073419edeb967fd0.bindTooltip(
#                 `&lt;div&gt;
#                      럭키 헬스
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_2c99827925f8b08d613f8394dec47fd8 = L.circle(
#                 [37.60008273, 127.1026847],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_81f864dae4c5e38710ab7136ec9fccb5);
#
#
#             circle_2c99827925f8b08d613f8394dec47fd8.bindTooltip(
#                 `&lt;div&gt;
#                      이코리아스포츠
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_94757da7e8719d80ec205378499b5677 = L.circle(
#                 [37.57908706, 127.0852681],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;:
